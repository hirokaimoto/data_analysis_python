# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.4.4

# %%
df = pd.read_csv('adult.data.csv')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.race.value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# mask = df.sex == 'Male'
# new = df[mask].age
# new.mean()
df[df.sex == 'Male'].age.mean()
# Out:
# 39.43354749885268

# %%
df[df.education == 'Bachelors'].education.count() / df.education.count() * 100
# Out:
# 16.44605509658794

# %%
df[((df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')) & (df.salary == '>50K')].education.count() / df[(df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')].education.count() * 100
# Out:
# 46.535843011613935

# %%
lower_education = df[((df.education != 'Bachelors') & (df.education != 'Masters') & (df.education != 'Doctorate')) & (df.salary == '>50K')].education.count() / df[(df.education != 'Bachelors') & (df.education != 'Masters') & (df.education != 'Doctorate')].education.count() * 100
lower_education
#     higher_education = df[((df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')) & (df.salary == '>50K')].education.count() / df[(df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')].education.count() * 100
#     lower_education = df[((df.education != 'Bachelors') & (df.education != 'Masters') & (df.education != 'Doctorate')) & (df.salary == '>50K')].education.count() / df[(df.education != 'Bachelors') & (df.education != 'Masters') & (df.education != 'Doctorate')].education.count() * 100
# Out:
# 17.3713601914639

# %%
mask = (df['hours-per-week'] == 1) & (df.salary == '>50K')
df[mask].education.count() / df[(df['hours-per-week'] == 1)].education.count() * 100
# Out:
# 10.0

# %%
mask = uber_data['review_rating'] == uber_data['review_rating'].min()
uber_data[mask]
# Out:
#      index      city state zipcode                             address  \
# 424    424  Bessemer    AL   35022  5000 Bond Blvd, Bessemer, AL 35022
#
#                                    loc_name  \
# 424  Leo's Italian Kitchen (5000 Bond Blvd)
#
#                                loc_number  \
# 424  26bcbf8f-5724-5f88-a721-dd879ee20974
#
#                                                    url promotion  latitude  \
# 424  https://www.ubereats.com/store/leos-italian-ki...       NaN   33.3329
#
#      longitude  is_open     closed_message  delivery_fee delivery_time  \
# 424  -86.99248    False  Opens at 10:30 AM           NaN           NaN
#
#      review_count  review_rating price_bucket            scan_date  TID
# 424          13.0            2.9           $$  2022-11-09 18:03:43  425

# %%
df[df.salary == '>50K']['native-country'].value_counts().idxmax()
df[(df.salary == '>50K') & (df['native-country'] == 'United-States')].salary.count() / df[df.salary == '>50K'].salary.count() * 100
# Out:
# 91.45517153424308

# %%
df[(df['native-country'] == 'India') & (df.salary == '>50K')].occupation.value_counts().idxmax()
# Out:
# 'Prof-specialty'

# %%
new = df[df.salary == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()
new.max()
# Out:
# 0.4186046511627907

# %%
new = df[df.salary == '>50K']['native-country'].value_counts().to_frame()
new['pop'] = df['native-country'].value_counts()
new['%'] = (new['native-country'] / new['pop'])
new
# Out:
#                     native-country    pop         %
# United-States                 7171  29170  0.245835
# ?                              146    583  0.250429
# Philippines                     61    198  0.308081
# Germany                         44    137  0.321168
# India                           40    100  0.400000
# Canada                          39    121  0.322314
# Mexico                          33    643  0.051322
# England                         30     90  0.333333
# Italy                           25     73  0.342466
# Cuba                            25     95  0.263158
# Japan                           24     62  0.387097
# Taiwan                          20     51  0.392157
# China                           20     75  0.266667
# Iran                            18     43  0.418605
# South                           16     80  0.200000
# Puerto-Rico                     12    114  0.105263
# Poland                          12     60  0.200000
# ...

# %%
uber_data.sort_values(by='index', ascending=False)
# Out:
#      index                               city state zipcode  \
# 999    999                             Hoover    AL   35244
# 998    998                             Hoover    AL   35244
# 997    997                         Birmingham    AL   35205
# 996    996  3321 Lorna Rd Birmingham AL 35216  3321   Lorna
# 995    995                         Birmingham    AL   35209
# ..     ...                                ...   ...     ...
# 4        4                     Alexander City    AL   35010
# 3        3                        Albertville    AL   35950
# 2        2                     Alexander City    AL   35010
# 1        1                        Albertville    AL   35951
# 0        0                     Alexander City    AL   35010
#
#                                                address  \
# 999            1790 Riverchase Drive, Hoover, AL 35244
# 998           3020 John Hawkins Pkwy, Hoover, AL 35244
# 997  1024 20th Street South Unit 101, Birmingham, A...
# ...
